# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("pokemon_data.csv")

# %%
data
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
data.describe()
# Out:
#                 #          HP      Attack  ...     Sp. Def       Speed  Generation
# count  800.000000  800.000000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750   69.258750   79.001250  ...   71.902500   68.277500     3.32375
# std    208.343798   25.534669   32.457366  ...   27.828916   29.060474     1.66129
# min      1.000000    1.000000    5.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000   50.000000   55.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000   65.000000   75.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  255.000000  190.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 8 columns]

# %%
data[data['Speed'] <= 43]
# Out:
#        #                 Name  Type 1  ... Speed  Generation  Legendary
# 9      7             Squirtle   Water  ...    43           1      False
# 14    11              Metapod     Bug  ...    30           1      False
# 17    14               Kakuna     Bug  ...    35           1      False
# 32    27            Sandshrew  Ground  ...    40           1      False
# 34    29     Nidoran (Female)  Poison  ...    41           1      False
# ..   ...                  ...     ...  ...   ...         ...        ...
# 774  704                Goomy  Dragon  ...    40           6      False
# 778  708             Phantump   Ghost  ...    38           6      False
# 783  710  PumpkabooSuper Size   Ghost  ...    41           6      False
# 788  712             Bergmite     Ice  ...    28           6      False
# 789  713              Avalugg     Ice  ...    28           6      False
#
# [173 rows x 12 columns]

# %%
data[data['HP'] == 45]
# Out:
#        #        Name    Type 1   Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 0      1   Bulbasaur     Grass   Poison  ...       65     45           1      False
# 13    10    Caterpie       Bug      NaN  ...       20     45           1      False
# 17    14      Kakuna       Bug   Poison  ...       25     35           1      False
# 48    43      Oddish     Grass   Poison  ...       65     30           1      False
# 100   93     Haunter     Ghost   Poison  ...       55     95           1      False
# 127  118     Goldeen     Water      NaN  ...       50     63           1      False
# 166  152   Chikorita     Grass      NaN  ...       65     45           2      False
# 243  225    Delibird       Ice   Flying  ...       45     75           2      False
# 246  228    Houndour      Dark     Fire  ...       50     65           2      False
# 257  238    Smoochum       Ice  Psychic  ...       65     65           2      False
# ...

# %%
data[(data['HP'] > 50) & (['Speed'] < 45)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-e38474e12f6e> in <module>()
# ----> 1 data[(data['HP'] > 50) & (['Speed'] < 45)]
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %% [markdown]
# ##Function Mapping and lambda
# lambda function is called by its assigned variable as the function doesn't have a name of its own

# %%
frame = pd.DataFrame(np.random.randn(4,3), columns = list('bde'),
                    index = ['Utah', 'Columbo', 'Texas', 'Oregon'])
frame
# Out:
#                 b         d         e
# Utah    -1.702209  0.625280 -0.210434
# Columbo  0.466245 -0.732101  0.483309
# Texas    0.814156 -0.344530  0.047182
# Oregon   0.772124 -1.032586  0.927660

# %%
frame.max()       #gives back the max value in each column
# Out:
# b    0.814156
# d    0.625280
# e    0.927660
# dtype: float64

# %%
frame.min()
# Out:
# b   -1.702209
# d   -1.032586
# e   -0.210434
# dtype: float64

# %%
frame.abs()
# Out:
#                 b         d         e
# Utah     1.702209  0.625280  0.210434
# Columbo  0.466245  0.732101  0.483309
# Texas    0.814156  0.344530  0.047182
# Oregon   0.772124  1.032586  0.927660

# %%
f = lambda x: x.max() - x.min()
frame.apply(f)
# Out:
# b    2.516365
# d    1.657866
# e    1.138093
# dtype: float64

# %%
f = lambda x: x ** 2
frame.apply(f)
# Out:
#                 b         d         e
# Utah     2.897515  0.390975  0.044282
# Columbo  0.217384  0.535972  0.233588
# Texas    0.662850  0.118701  0.002226
# Oregon   0.596175  1.066234  0.860552

# %% [markdown]
# ##Sorting and Ranking

# %%
obj = pd.Series(range(4), index = [1,9,3,7])
obj
# Out:
# 1    0
# 9    1
# 3    2
# 7    3
# dtype: int64

# %%
obj.sort_index(ascending = False)
# Out:
# 9    1
# 7    3
# 3    2
# 1    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2,4)),
                     index = ['three','one'],
                     columns = ['d','e','a','c'])
frame
# Out:
#        d  e  a  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame.sort_index()
# Out:
#        d  e  a  c
# one    4  5  6  7
# three  0  1  2  3

# %%
frame = pd.DataFrame(np.arange(8, 0 , -1).reshape((2,4)),
                     index = ['three','one'],
                     columns = ['d','e','a','c'])
frame
# Out:
#        d  e  a  c
# three  8  7  6  5
# one    4  3  2  1

# %%
frame.sort_values(by = 'a')
# Out:
#        d  e  a  c
# one    4  3  2  1
# three  8  7  6  5

# %%
data = pd.read_csv('data.csv')
data
# Out:
#      Student Code  Degree  ... Total (100)  Grade
# 0    022-14-19987  BS(CS)  ...          70      B
# 1   022-14-110233  BS(CS)  ...          50      F
# 2   022-14-110585  BS(CS)  ...          63      C
# 3    022-14-19718  BS(CS)  ...          46      F
# 4   022-14-110648  BS(CS)  ...          77      B
# 5   022-14-110232  BS(CS)  ...          71      B
# 6   022-14-110588  BS(CS)  ...          74      B
# 7   022-14-110388  BS(CS)  ...          85      A
# 8   022-14-110601  BS(CS)  ...          61      C
# 9   022-14-110599  BS(CS)  ...          84      A
# 10  022-14-110214  BS(CS)  ...          91      A
# 11  022-14-110591  BS(CS)  ...          76      B
# 12  022-15-110994  BS(CS)  ...          73      B
# 13  022-14-110600  BS(CS)  ...          67      C
# 14  022-14-110389  BS(CS)  ...          65      C
# 15   022-14-19916  BS(CS)  ...          18      F
# 16  022-14-110596  BS(CS)  ...          72      B
# 17  022-14-110396  BS(CS)  ...          70      B
# ...

# %%
data.sort_values(by = 'Best of Quizzes', ascending = False)
# Out:
#      Student Code  Degree  ... Total (100)  Grade
# 47  022-14-110219  BS(CS)  ...          46      F
# 7   022-14-110388  BS(CS)  ...          85      A
# 25  022-14-110105  BS(CS)  ...          86      A
# 34  022-14-110413  BS(CS)  ...          86      A
# 36  022-14-110582  BS(CS)  ...          70      B
# 37  022-14-110230  BS(CS)  ...          75      B
# 19  022-14-110222  BS(CS)  ...          91      A
# 8   022-14-110601  BS(CS)  ...          61      C
# 40  022-14-110584  BS(CS)  ...          81      A
# 5   022-14-110232  BS(CS)  ...          71      B
# 43  022-14-110451  BS(CS)  ...          79      B
# 45  022-14-110400  BS(CS)  ...          80      A
# 21  022-14-110593  BS(CS)  ...          60      C
# 35   022-14-19923  BS(CS)  ...          66      C
# 30  022-14-110401  BS(CS)  ...          72      B
# 27  022-14-110452  BS(CS)  ...          71      B
# 46   022-14-19911  BS(CS)  ...          65      C
# 0    022-14-19987  BS(CS)  ...          70      B
# ...

# %%
data.sort_values(by = ['Quiz 1', 'Quiz 2'], ascending = False)
# Out:
#      Student Code  Degree  ... Total (100)  Grade
# 5   022-14-110232  BS(CS)  ...          71      B
# 7   022-14-110388  BS(CS)  ...          85      A
# 19  022-14-110222  BS(CS)  ...          91      A
# 21  022-14-110593  BS(CS)  ...          60      C
# 25  022-14-110105  BS(CS)  ...          86      A
# 34  022-14-110413  BS(CS)  ...          86      A
# 40  022-14-110584  BS(CS)  ...          81      A
# 45  022-14-110400  BS(CS)  ...          80      A
# 36  022-14-110582  BS(CS)  ...          70      B
# 37  022-14-110230  BS(CS)  ...          75      B
# 47  022-14-110219  BS(CS)  ...          46      F
# 8   022-14-110601  BS(CS)  ...          61      C
# 43  022-14-110451  BS(CS)  ...          79      B
# 10  022-14-110214  BS(CS)  ...          91      A
# 9   022-14-110599  BS(CS)  ...          84      A
# 27  022-14-110452  BS(CS)  ...          71      B
# 30  022-14-110401  BS(CS)  ...          72      B
# 11  022-14-110591  BS(CS)  ...          76      B
# ...

# %%
data.sort_values(by = ['Best of Quizzes', 'Assignment 1'], ascending = False)
# Out:
#      Student Code  Degree  ... Total (100)  Grade
# 21  022-14-110593  BS(CS)  ...          60      C
# 36  022-14-110582  BS(CS)  ...          70      B
# 37  022-14-110230  BS(CS)  ...          75      B
# 45  022-14-110400  BS(CS)  ...          80      A
# 5   022-14-110232  BS(CS)  ...          71      B
# 7   022-14-110388  BS(CS)  ...          85      A
# 19  022-14-110222  BS(CS)  ...          91      A
# 25  022-14-110105  BS(CS)  ...          86      A
# 34  022-14-110413  BS(CS)  ...          86      A
# 40  022-14-110584  BS(CS)  ...          81      A
# 8   022-14-110601  BS(CS)  ...          61      C
# 43  022-14-110451  BS(CS)  ...          79      B
# 47  022-14-110219  BS(CS)  ...          46      F
# 17  022-14-110396  BS(CS)  ...          70      B
# 30  022-14-110401  BS(CS)  ...          72      B
# 9   022-14-110599  BS(CS)  ...          84      A
# 10  022-14-110214  BS(CS)  ...          91      A
# 13  022-14-110600  BS(CS)  ...          67      C
# ...

# %%
pd.options.display.max_rows = 10

# %%
obj = pd.Series([-4,2,5,-7,2,1])
obj
# Out:
# 0   -4
# 1    2
# 2    5
# 3   -7
# 4    2
# 5    1
# dtype: int64

# %%
obj.sort_values(inplace = True)
obj
# Out:
# 3   -7
# 0   -4
# 5    1
# 1    2
# 4    2
# 2    5
# dtype: int64

# %%
obj.rank(method = 'first')
# Out:
# 3    1.0
# 0    2.0
# 5    3.0
# 1    4.0
# 4    5.0
# 2    6.0
# dtype: float64

# %%
obj.rank()                #gives mean of duplicate values
# Out:
# 3    1.0
# 0    2.0
# 5    3.0
# 1    4.5
# 4    4.5
# 2    6.0
# dtype: float64

# %%
arr = np.array([3,4,5,6,7,8,4])

# %%
arr.max()           #value (numpy)
# Out:
# 8

# %%
arr.argmax()        #index (numpy)
# Out:
# 5

# %%
arr.min()
# Out:
# 3

# %%
arr.argmin()
# Out:
# 0

# %%
data['Mid'].max()              #value (pandas)
# Out:
# 30

# %%
data['Mid'].idxmax()           #index (pandas)
# Out:
# 10

# %% [markdown]
# #Dictionary Comprehension

# %%
import pandas_datareader.data as web

# %%
all_data = { ticker: web.get_data_yahoo(ticker)
           for ticker in ['AAPL','IBM','MSFT','GOOG']}
all_data
# Out:
# {'AAPL':                   High         Low  ...       Volume   Adj Close
#  Date                                ...
#  2010-01-04   30.642857   30.340000  ...  123432400.0   26.681330
#  2010-01-05   30.798571   30.464285  ...  150476200.0   26.727465
#  2010-01-06   30.747143   30.107143  ...  138040000.0   26.302330
#  2010-01-07   30.285715   29.864286  ...  119282800.0   26.253704
#  2010-01-08   30.285715   29.865715  ...  111902700.0   26.428249
#  ...                ...         ...  ...          ...         ...
#  2019-10-21  240.990005  237.320007  ...   21811800.0  240.509995
#  2019-10-22  242.199997  239.619995  ...   20573400.0  239.960007
#  2019-10-23  243.240005  241.220001  ...   18957200.0  243.179993
#  2019-10-24  244.800003  241.809998  ...   17318800.0  243.580002
#  2019-10-25  246.729996  242.880005  ...   18330500.0  246.580002
#
#  [2471 rows x 6 columns],
#  'GOOG':                    High          Low  ...      Volume    Adj Close
# ...

# %%
price = pd.DataFrame({ticker:data['Adj Close']
                     for ticker, data in all_data.items()})
price
# Out:
#                   AAPL         IBM        MSFT         GOOG
# Date
# 2010-01-04   26.681330   98.142967   24.443624   312.204773
# 2010-01-05   26.727465   96.957375   24.451517   310.829926
# 2010-01-06   26.302330   96.327530   24.301458   302.994293
# 2010-01-07   26.253704   95.994110   24.048725   295.940735
# 2010-01-08   26.428249   96.957375   24.214581   299.885956
# ...                ...         ...         ...          ...
# 2019-10-21  240.509995  132.580002  138.429993  1246.150024
# 2019-10-22  239.960007  133.960007  136.369995  1242.800049
# 2019-10-23  243.179993  134.380005  137.240005  1259.130005
# 2019-10-24  243.580002  134.070007  139.940002  1260.989990
# 2019-10-25  246.580002  135.440002  140.729996  1265.130005
#
# [2471 rows x 4 columns]

# %%
volume = pd.DataFrame({ticker : data['Volume']
                       for ticker, data in all_data.items()})

# %%
returns = price.pct_change()
returns
# Out:
#                 AAPL       IBM      MSFT      GOOG
# Date
# 2010-01-04       NaN       NaN       NaN       NaN
# 2010-01-05  0.001729 -0.012080  0.000323 -0.004404
# 2010-01-06 -0.015906 -0.006496 -0.006137 -0.025209
# 2010-01-07 -0.001849 -0.003461 -0.010400 -0.023280
# 2010-01-08  0.006648  0.010035  0.006897  0.013331
# ...              ...       ...       ...       ...
# 2019-10-21  0.017343 -0.011261  0.007423  0.000530
# 2019-10-22 -0.002287  0.010409 -0.014881 -0.002688
# 2019-10-23  0.013419  0.003135  0.006380  0.013140
# 2019-10-24  0.001645 -0.002307  0.019674  0.001477
# 2019-10-25  0.012316  0.010219  0.005645  0.003283
#
# [2471 rows x 4 columns]

# %%
returns['MSFT'].corr(returns['IBM'])
# Out:
# 0.49063098945954964

# %%
returns['MSFT'].cov(returns['IBM'])
# Out:
# 8.768699044850248e-05

# %%
returns.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.385471  0.457804  0.464060
# IBM   0.385471  1.000000  0.490631  0.405930
# MSFT  0.457804  0.490631  1.000000  0.540471
# GOOG  0.464060  0.405930  0.540471  1.000000

# %%
returns.corrwith(returns.IBM)
# Out:
# AAPL    0.385471
# IBM     1.000000
# MSFT    0.490631
# GOOG    0.405930
# dtype: float64

# %%
##Unique values

# %%
obj = pd.Series(['a','a','b','c','e','a'])
obj.unique()
# Out:
# array(['a', 'b', 'c', 'e'], dtype=object)

# %%
obj.count()
# Out:
# 6

# %%
obj.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# dtype: bool
